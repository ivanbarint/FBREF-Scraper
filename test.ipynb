# %%
import fbref_functions
import pandas as pd

# %%
dir(fbref_functions)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'keeper_full_seasonal_stats',
#  'player_full_seasonal_stats',
#  'player_seasonal_stats',
#  'results_and_fixtures',
#  'team_seasonal_opp_stats',
#  'team_seasonal_stats']

# %%
fbref_functions.results_and_fixtures()
# Out:
# Enter competition: eng
# Enter season: 2019
# /Users/ivanbarin-turica/FBREF-Scraper/scores_and_fixtures.py:41: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors='ignore')
#      gameweek dayofweek       date start_time        home_team  home_xg  \
# 0         1.0       Fri 2019-08-09     20:00         Liverpool      1.8
# 1         1.0       Sat 2019-08-10     12:30          West Ham      1.1
# 2         1.0       Sat 2019-08-10     15:00           Burnley      0.9
# 3         1.0       Sat 2019-08-10     15:00           Watford      0.7
# 4         1.0       Sat 2019-08-10     15:00    Crystal Palace      0.9
# ..        ...       ...        ...        ...              ...      ...
# 375      38.0       Sun 2020-07-26     16:00   Manchester City      3.2
# 376      38.0       Sun 2020-07-26     16:00           Chelsea      1.4
# ...

# %%
import scores_and_fixtures

# %%
dir(scores_and_fixtures)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__warningregistry__',
#  'season_results_and_fixtures']

# %%
df = pd.DataFrame()

# %%
for i in range(2018, 2025):
    season_df = scores_and_fixtures.season_results_and_fixtures("eng", i)
    df = pd.concat([df, season_df])
# Out:
# /Users/ivanbarin-turica/FBREF-Scraper/scores_and_fixtures.py:41: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors='ignore')
# /Users/ivanbarin-turica/FBREF-Scraper/scores_and_fixtures.py:41: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors='ignore')
# /Users/ivanbarin-turica/FBREF-Scraper/scores_and_fixtures.py:41: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors='ignore')
# ...

# %%
df = df[['home_team', 'away_team', 'home_score', 'away_score']]

# %%
goals = 0

for i, row in df.iterrows():
    if row['home_team'] == "Arsenal":
        rpitn
        goals = goals + row['home_score']
    elif row['away_team'] == "Arsenal":
        goals = goals + row['away_score']

# %%
goals
# Out:
# nan
