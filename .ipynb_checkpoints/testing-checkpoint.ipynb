# %%
import pandas as pd
import numpy as np

import requests
from bs4 import BeautifulSoup

import time

import warnings
warnings.filterwarnings('ignore')

# %%
def fetch_player_data(url):
    
    resp = requests.get(url)
    resp.encoding = 'utf-8'
    soup = BeautifulSoup(resp.text.replace('<!--', '').replace('--!>', ''), 'html.parser')

    headers, rows = [], []

    table_data = soup.find_all('tbody')[2]
    table_rows = table_data.find_all('tr')

    for value in table_rows[0]:
        headers.append(value.get('data-stat'))

    for row in table_rows:
        row_values = []
        row_data = row.find_all('td')
        for data_value in row_data:
            if data_value.get('data-append-csv'):
                row_values.append(data_value.get('data-append-csv'))
            row_values.append(data_value.get_text())
        rows.append(row_values)

    df = pd.DataFrame(rows, columns = headers).fillna(0)
    df = df.loc[df['player'] != 0].reset_index(drop = True)

    if 'minutes' in headers:
        df['minutes'] = df['minutes'].str.replace(',', '')
    elif 'gk_minutes' in headers:
        df['gk_minutes'] = df['gk_minutes'].str.replace(',', '')

    for i, row in df.iterrows():
        try:
            if '-' in row['age']:
                age_num = row['age'].split('-')[0]
                df.at[i, 'age'] = age_num
        except: pass

    df.rename(columns={'ranker' : 'player_id'}, inplace=True)
    df = df.apply(pd.to_numeric, errors = 'ignore')
    
    return df

# %%
def check_comp(comp):
    output = ""
    if comp.lower() == 'england' or comp.lower() == "premier_league" or comp.lower() == "eng":
        league_code = 9
        league_name = "Premier-League"
    elif comp.lower() == 'spain' or comp.lower() == "la_liga" or comp.lower() == "esp":
        league_code = 12
        league_name = "La-Liga"
    elif comp.lower() == 'italy' or comp.lower() == "serie-a" or comp.lower() == "ita":
        league_code = 11
        league_name = "Serie-A"
    elif comp.lower() == 'germany' or comp.lower() == "bundesliga" or comp.lower() == "ger":
        league_code = 20
        league_name = "Bundesliga"
    elif comp.lower() == 'france' or comp.lower() == "ligue-1" or comp.lower() == "fra":
        league_code = 13
        league_name = "Ligue-1"
    return league_code, league_name

# %%
def get_data(competition, year, data_type):
    
    comp = check_comp(competition)
    season = f"{str(year)}-{str(year+1)}"
    url = f"https://fbref.com/en/comps/{comp[0]}/{season}/{data_type}/{season}-{comp[1]}-Stats"
    df = fetch_player_data(url)
    
    return df

# %%
df = get_data("eng", 2022, "keepers")

# %%
df
# Out:
#    player_id              player nationality position            team  age  \
# 0   47064058      Oliver Baumann      de GER       GK      Hoffenheim   32
# 1   663e080e      Janis Blaswich      de GER       GK      RB Leipzig   31
# 2   d28339cb      Fabian Bredlow      de GER       GK       Stuttgart   27
# 3   db401046       Koen Casteels      be BEL       GK       Wolfsburg   30
# 4   af104654  Oliver Christensen      dk DEN       GK      Hertha BSC   23
# 5   dee3013b         Finn Dahmen      de GER       GK        Mainz 05   24
# 6   3f6c3ae0         Tjark Ernst      de GER       GK      Hertha BSC   19
# 7   1e43fad8       Ralf Fährmann      de GER       GK      Schalke 04   33
# 8   a92ab7be        Mark Flekken      nl NED       GK        Freiburg   29
# 9   17376543     Rafał Gikiewicz      pl POL       GK        Augsburg   34
# 10  37998008       Lennart Grill      de GER       GK    Union Berlin   23
# 11  bcb2ccd8       Péter Gulácsi      hu HUN       GK      RB Leipzig   32
# 12  ad3389d5      Lukáš Hrádecký      fi FIN       GK      Leverkusen   32
# 13  cd59b9df        Gregor Kobel      ch SUI       GK        Dortmund   24
# 14  dc366c36        Tomáš Koubek      cz CZE       GK        Augsburg   29
# 15  8a6ab963       Andrey Lunyov      ru RUS       GK      Leverkusen   30
# 16  b56dd813     Alexander Meyer      de GER       GK        Dortmund   31
# 17  cbac6ec9      Florian Müller      de GER       GK       Stuttgart   24
# 18  8778c910        Manuel Neuer      de GER       GK   Bayern Munich   36
# 19  bdedffac        Ørjan Nyland      no NOR       GK      RB Leipzig   31
# 20  fa4cabd1      Jan Olschowsky      de GER       GK        Gladbach   20
# 21  c631f952         Jonas Omlin      ch SUI       GK        Gladbach   28
# 22  0a1cb833       Jiří Pavlenka      cz CZE       GK   Werder Bremen   30
# 23  b90c4a43         Diant Ramaj      de GER       GK  Eint Frankfurt   20
# 24  9f941969      Manuel Riemann      de GER       GK          Bochum   33
# 25  a70b8345     Frederik Rønnow      dk DEN       GK    Union Berlin   29
# 26  87436846      Marvin Schwäbe      de GER       GK            Köln   27
# 27  0d55d942  Alexander Schwolow      de GER       GK      Schalke 04   30
# 28  0d8a37c2       Tobias Sippel      de GER       GK        Gladbach   34
# 29  420c18a1         Yann Sommer      ch SUI       GK        Gladbach   33
# 30  420c18a1         Yann Sommer      ch SUI       GK   Bayern Munich   33
# 31  ce17b5eb         Kevin Trapp      de GER       GK  Eint Frankfurt   32
# 32  7d3e7da6        Sven Ulreich      de GER       GK   Bayern Munich   33
# 33  5c4bf6ba       Robin Zentner      de GER       GK        Mainz 05   27
# 34  9b688ae1    Michael Zetterer      de GER       GK   Werder Bremen   27
#
#     birth_year  gk_games  gk_games_starts  gk_minutes  ...  gk_ties  \
# 0         1990        34               34        3060  ...        6
# 1         1991        26               26        2340  ...        4
# 2         1995        15               15        1350  ...        5
# 3         1992        34               34        3060  ...       10
# 4         1999        33               33        2970  ...        8
# 5         1998         8                8         720  ...        2
# 6         2003         1                1          90  ...        0
# 7         1988        12               12        1025  ...        6
# 8         1993        34               34        3060  ...        8
# 9         1987        23               23        2070  ...        3
# 10        1999         5                5         450  ...        1
# 11        1990         6                6         540  ...        2
# 12        1989        33               33        2969  ...        8
# 13        1997        27               27        2430  ...        3
# 14        1992        11               11         990  ...        4
# 15        1991         1                1          90  ...        0
# 16        1991         7                7         630  ...        2
# 17        1997        19               19        1710  ...        7
# 18        1986        12               12        1080  ...        4
# 19        1990         2                2         180  ...        0
# 20        2001         4                4         360  ...        1
# 21        1994        15               15        1290  ...        4
# 22        1992        33               33        2908  ...        5
# 23        2001         1                1          90  ...        1
# 24        1988        34               34        3060  ...        5
# 25        1992        29               29        2610  ...        7
# 26        1995        34               34        3060  ...       12
# 27        1992        23               22        2035  ...        4
# 28        1988         6                5         510  ...        1
# 29        1988        10               10         900  ...        4
# 30        1988        19               19        1710  ...        4
# 31        1990        33               33        2970  ...       10
# 32        1988         3                3         270  ...        0
# 33        1994        26               26        2340  ...        8
# 34        1995         2                1         152  ...        1
#
#     gk_losses  gk_clean_sheets  gk_clean_sheets_pct  gk_pens_att  \
# 0          18                5                 14.7            3
# 1           6                7                 26.9            7
# 2           6                1                  6.7            5
# 3          11               12                 35.3            7
# 4          19                3                  9.1            6
# 5           3                0                  0.0            3
# 6           0                0                  0.0            0
# 7           3                5                 41.7            2
# 8           9               13                 38.2            6
# 9          12                5                 21.7            4
# 10          2                2                 40.0            2
# 11          2                2                 33.3            1
# 12         11                9                 27.3            7
# 13          5               11                 40.7            1
# 14          6                1                  9.1            0
# 15          1                0                  0.0            0
# 16          2                1                 14.3            0
# 17          9                1                  5.3            1
# 18          1                4                 33.3            2
# 19          0                1                 50.0            0
# 20          2                0                  0.0            1
# 21          6                5                 33.3            2
# 22         18                4                 12.1            3
# 23          0                0                  0.0            0
# 24         19                5                 14.7           14
# 25          6               11                 37.9            5
# 26         12                6                 17.6            5
# 27         14                2                  9.1            4
# 28          3                1                 20.0            1
# 29          2                3                 30.0            2
# 30          4                5                 26.3            7
# 31         10                6                 18.2            2
# 32          0                2                 66.7            1
# 33          9                7                 26.9            5
# 34          0                0                  0.0            0
#
#     gk_pens_allowed  gk_pens_saved  gk_pens_missed  gk_pens_save_pct  matches
# 0                 2              0               1               0.0  Matches
# 1                 6              1               0              14.3  Matches
# 2                 5              0               0               0.0  Matches
# 3                 4              1               2              20.0  Matches
# 4                 5              1               0              16.7  Matches
# 5                 1              2               0              66.7  Matches
# 6                 0              0               0               NaN  Matches
# 7                 1              0               1               0.0  Matches
# 8                 5              0               1               0.0  Matches
# 9                 1              2               1              66.7  Matches
# 10                2              0               0               0.0  Matches
# 11                1              0               0               0.0  Matches
# 12                7              0               0               0.0  Matches
# 13                1              0               0               0.0  Matches
# 14                0              0               0               NaN  Matches
# 15                0              0               0               NaN  Matches
# 16                0              0               0               NaN  Matches
# 17                1              0               0               0.0  Matches
# 18                2              0               0               0.0  Matches
# 19                0              0               0               NaN  Matches
# 20                1              0               0               0.0  Matches
# 21                2              0               0               0.0  Matches
# 22                2              1               0              33.3  Matches
# 23                0              0               0               NaN  Matches
# 24                8              3               3              27.3  Matches
# 25                5              0               0               0.0  Matches
# 26                4              1               0              20.0  Matches
# 27                4              0               0               0.0  Matches
# 28                1              0               0               0.0  Matches
# 29                2              0               0               0.0  Matches
# 30                7              0               0               0.0  Matches
# 31                2              0               0               0.0  Matches
# 32                0              1               0             100.0  Matches
# 33                3              1               1              25.0  Matches
# 34                0              0               0               NaN  Matches
#
# [35 rows x 27 columns]
